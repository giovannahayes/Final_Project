# %%
import pandas as pd
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import csv
import seaborn as sns
from collections import Counter

import statistics as stats

from numpy.random import seed

import seaborn as sns; sns.set()

import os

import warnings

# %%
#Store CSV into Dataframe

df = "./Resources/test.csv"
test_df = pd.read_csv(df,encoding='latin-1')
test_df
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes         0.0      Graduate            No
# 1    LP001022   Male     Yes         1.0      Graduate            No
# 2    LP001031   Male     Yes         2.0      Graduate            No
# 3    LP001035   Male     Yes         2.0      Graduate            No
# 4    LP001051   Male      No         0.0  Not Graduate            No
# ..        ...    ...     ...         ...           ...           ...
# 362  LP002971   Male     Yes         3.0  Not Graduate           Yes
# 363  LP002975   Male     Yes         0.0      Graduate            No
# 364  LP002980   Male      No         0.0      Graduate            No
# 365  LP002986   Male     Yes         0.0      Graduate            No
# 366  LP002989   Male      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#lets see how many values are in the data frame
test_df.shape
# Out:
# (367, 12)

# %%
#lets see which columns have null values
test_df.isna().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
#given the the column with the highest percentage of missing values is less than 8% we will remove any row with a null value
test_df = test_df.dropna(how='any',axis=0)

# %%
#lets check the null values again
test_df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
#lets look for duplicated Loan IDs in the data set
test_df[test_df.duplicated(['Loan_ID'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
#lets save this pandas dataframe as a csv file so we can import it into our database

test_df.to_csv(r'C:/Users/Brian/Desktop/Final_Project/Resources/finaltest_df.csv', index = False)
